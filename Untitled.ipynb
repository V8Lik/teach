# %%
import matplotlib.pyplot as plt 
import numpy as np
import math

# %%
def first_func(a, b, c):
    return math.fabc(a * b + c)

# %%
x = np.arange(3, 11.1 , 1)

for arg in x:
    print(first_func(-3, arg, 21))

print(x)
# Out:
# [ 3.  4.  5.  6.  7.  8.  9. 10. 11.]

# %%
plt.xlabel("x")
plt.ylabel("f(x)")

y_list = np.arange(0, 20.01, 1)

x_list = np.arange(0, 20.01, 1)

plt.plot(x, y, color = "red", linewidth = 1)

plt.yticks(y_list)
plt.xticks(x_list)

plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       4 y_list = np.arange(0, 20.01, 1)
#       5
#       6 x_list = np.arange(0, 20.01, 1)
#       7
# ----> 8 plt.plot(x, y, color = "red", linewidth = 1)
#       9
#      10 plt.yticks(y_list)
#      11 plt.xticks(x_list)
#
# NameError: name 'y' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
import random as rnd
import math

# %%
def sin_func(x, a, b, c, d):
    return a * math.sin(b * x + c) + d

# Коэффициент a изменяет амплитуду (разница между верхним и нижним пиком) синусоиды
# Если a = 2   , то амплитуда будет в два раза ВЫШЕ стандартной
# Если a = 0.5 , то амплитуда будет в два раза НИЖЕ стандартной

# Коэффициент b изменяет частоту (кол-во волн на одном и том же промежутке) синусоиды
# Если b = 2   , то частота возрастает в два раза больше стандартной (на одном промежутке становится больше волн, а размер волн сокращается)
# Если b = 0.5 , то частота падает в два раза меньше стандартной

# Коэффициент c изменяет горизонтальное положение синусоиды
    # Если с = 1   , то синусоида двигается влево
    # Если c = -1 , то синусоида двигается вправо
    
# Коэффициент d изменяет вертикальное положение синусоиды
    # Если d = 1   , то синусоида двигается вверх
    # Если d = -1 , то синусоида двигается вниз

# Графики коэффициентов d
#plot_yd1 = plt.plot(x, yd1, color = "red", linewidth = 1)
#plot_yd_1 = plt.plot(x, yd_1, color = "blue", linewidth = 1)

# %%
x = np.arange(0, 20, 0.1)

print(x)

# %%
y_standart = []

ya2 = []
ya05 = []

yb2 = []
yb05 = []

for arg in x:
    y_standart.append(sin_func(arg, 1, 1, 0, 0))

# Исследование коэффициента a
# ya2.append( sin_func(arg, 2, 1, 0, 0) )
# ya05.append( sin_func(arg, 0.5, 1, 0, 0) )

# Исследование коэффициента b
# yb2.append( sin_func(arg, 1, 2, 0, 0) )
# yb05.append( sin_func(arg, 1, 0.5, 0, 0) )

# Исследование коэффициента c
    #yc1.append( sin_func(arg, 1, 1, 1, 0) )
    #yc_1.append( sin_func(arg, 1, 1, -1, 0) )

# Исследование коэффициента d
    #yd1.append( sin_func(arg, 1, 1, 0, 1) )
    #yd_1.append( sin_func(arg, 1, 1, 0, -1) )
    
print(y_standart)

# %%
plot_standart = plt.plot(x, y_standart, color='orange', linewidth = 3)

# Графики коэффициентов a
# plot_ya2 = plt.plot(x, ya2, color = "red", linewidth = 1)
# plot_ya05 = plt.plot(x, ya05, color = "yellow", linewidth = 1)

# Графики коэффициентов b
#plot_yb2 = plt.plot(x, yb2, color = "red", linewidth = 1)
#plot_yb05 = plt.plot(x, yb05, color = "yellow", linewidth = 1)

# Графики коэффициентов c
#plot_yc1 = plt.plot(x, yc1, color = "red", linewidth = 1)
#plot_yc_1 = plt.plot(x, yc_1, color = "blue", linewidth = 1)

# Графики коэффициентов d
#plot_yd1 = plt.plot(x, yd1, color = "red", linewidth = 1)
#plot_yd_1 = plt.plot(x, yd_1, color = "blue", linewidth = 1)

plt.xlabel('x')
plt.ylabel('F(x)')
plt.title("Синусоиды")

plt.grid()
plt.show()
